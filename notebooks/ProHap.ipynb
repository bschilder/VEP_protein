# %% [markdown]
# # ProHap/Provar

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir(os.path.dirname(os.path.abspath('.')))

import pandas as pd
import src.utils as utils
import src.prohap as ph
import src.onekg as ok
pd.set_option('display.max_columns', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Install

# %%
# %% bash
#
# # Clone this repository:
# git clone https://github.com/ProGenNo/ProHap.git ;
# cd ProHap;
#
# # Unpack the sample dataset
# cd sample_data ;
# gunzip sample_1kGP_common_global.tar.gz ;
# tar xf sample_1kGP_common_global.tar ;
# cd .. ;
#
# # Copy the configuration to config.yaml
# cp config_example1.yaml config.yaml ;
#
# # Create snakemake conda environment
# conda create -c conda-forge -c bioconda -n snakemake snakemake conda

# %% [markdown]
# ## Run

# %%
# %% bash
#
# # Activate the snakemake conda environment and run the pipeline
# conda activate snakemake ;
# snakemake --cores 4 -p --use-conda ;

# %% [markdown]
# ### Human_Genome_Diversity_Project

# %%
vcf_files = ok.download_vcfs(key="Human_Genome_Diversity_Project")
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 vcf_files = ok.download_vcfs(key="Human_Genome_Diversity_Project")
#
# File ~/projects/VEP_protein/src/onekg.py:158, in download_vcfs(key, manifest, skip_checks, cache, timeout, as_dict, verbose)
#     156         local_file = row['local']
#     157     else:
# --> 158         local_file = pooch.retrieve(
#     159             url=row['url'],
#     160             fname=os.path.basename(row['local']),
#     161             path=os.path.dirname(row['local']),
#     162             known_hash="md5:"+row['md5'] if 'md5' in row else None,
#     163             progressbar=True
#     164         )
#     165     local_files[os.path.basename(row['local'])] = local_file
#     167 if as_dict:
#
# ...

# %% [markdown]
# ## Download precomputed haplotypes

# %%
zenodo_files = ph.get_zenodo(['1KG','HRC','HPRC'])
# Out:
# ...
# 100%|████████████████████████████████████████| 166M/166M [00:00<00:00, 548GB/s]
# Untarring contents of '/home/schilder/.cache/pooch/240703_ProHap_pangenome_ALL.tar.gz' to '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar'
# ...
# 100%|█████████████████████████████████████| 1.44k/1.44k [00:00<00:00, 2.44MB/s]

# %%
zenodo_files
# Out:
# {'1KG': {'data': ['/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F1.2_240527_ens110_ref_contam_1kGP_ALL_GRCh38_haplo_header.tsv',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F1_240527_ens110_ref_contam_1kGP_ALL_GRCh38_haplo.fa',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F1_240527_ens110_ref_contam_1kGP_ALL_GRCh38_haplo_simplified.fa',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F2_240527_1kGP_ALL_GRCh38_haplo.tsv',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F3_240527_1kGP_ALL_GRCh38_haplo.fa',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F1_240703_ens110_ref_contam_HRC1.1_GRCh38_haplo.fa',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F1_240703_ens110_ref_contam_HRC1.1_GRCh38_haplo_simplified.fasta',
#    '/home/schilder/.cache/pooch/240527_ProHap_ALL.tar.gz.untar/F1.2_240703_ens110_ref_contam_HRC1.1_GRCh38_haplo_header.tsv',
# ...
