# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pooch
import polars as pl
import os

# %%
study_index = pd.read_json("https://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/22.02.01/lut/study-index/part-00000-2e5fae34-19dc-4dff-8f46-9d8a6fc11895-c000.json", lines=True)
study_index.head()
# Out:
#                                       study_id   pub_date  pub_author  \
# 0                    FINNGEN_R5_AB1_AMOEBIASIS  2021-5-11  FINNGEN_R5
# 1     FINNGEN_R5_AB1_ANOGENITAL_HERPES_SIMPLEX  2021-5-11  FINNGEN_R5
# 2                     FINNGEN_R5_AB1_ARTHROPOD  2021-5-11  FINNGEN_R5
# 3                 FINNGEN_R5_AB1_ASPERGILLOSIS  2021-5-11  FINNGEN_R5
# 4            FINNGEN_R5_AB1_ATYPICAL_CNS_VIRUS  2021-5-11  FINNGEN_R5
# ...                                        ...        ...         ...
# 1263              FINNGEN_R5_H7_SEVVISIMPMONOC  2021-5-11  FINNGEN_R5
# 1264                  FINNGEN_R5_H7_STENOLACRI  2021-5-11  FINNGEN_R5
# 1265                  FINNGEN_R5_H7_STRABISMUS  2021-5-11  FINNGEN_R5
# 1266                    FINNGEN_R5_H7_STRABNAS  2021-5-11  FINNGEN_R5
# 1267                    FINNGEN_R5_H7_STRABOTH  2021-5-11  FINNGEN_R5
#
#                                          trait_reported   ancestry_initial  \
# 0                                            Amoebiasis  [European=197385]
# 1     Anogenital herpesviral [herpes simplex] infection  [European=213843]
# 2     Arthropod-borne viral fevers and viral haemorr...  [European=218792]
# 3                                         Aspergillosis  [European=214903]
# 4     Atypical virus infections of central nervous s...  [European=217783]
# ...                                                 ...                ...
# 1263              "Severe visual impairment, monocular"  [European=210946]
# 1264    Stenosis and insufficiency of lacrimal passages  [European=204549]
# 1265                                         Strabismus  [European=218792]
# 1266         Other specified and unspecified strabismus  [European=211071]
# 1267                                   Other strabismus  [European=214760]
#
#      ancestry_replication  n_initial  n_replication  n_cases  num_assoc_loci  \
# 0                      []     197385              0       87               0
# 1                      []     213843              0      891               0
# 2                      []     218792              0     1450               0
# 3                      []     214903              0       87               0
# 4                      []     217783              0      146               0
# ...                   ...        ...            ...      ...             ...
# 1263                   []     210946              0       80               0
# 1264                   []     204549              0     1318               0
# 1265                   []     218792              0     4620               0
# 1266                   []     211071              0      140               0
# 1267                   []     214760              0     3829               0
#
#       has_sumstats   source                    trait_efos  \
# 0             True  FINNGEN                 [EFO_0007144]
# 1             True  FINNGEN                 [EFO_0007282]
# 2             True  FINNGEN  [MONDO_0018087, EFO_0000763]
# 3             True  FINNGEN                 [EFO_0007157]
# 4             True  FINNGEN               [MONDO_0024318]
# ...            ...      ...                           ...
# 1263          True  FINNGEN               [MONDO_0001941]
# 1264          True  FINNGEN                  [HP_0000614]
# 1265          True  FINNGEN                  [HP_0000486]
# 1266          True  FINNGEN                  [HP_0000486]
# 1267          True  FINNGEN                  [HP_0000486]
#
#                 trait_category
# 0           infectious disease
# 1           infectious disease
# 2           infectious disease
# 3           infectious disease
# 4           infectious disease
# ...                        ...
# 1263  disease of visual system
# 1264                 phenotype
# 1265                 phenotype
# 1266                 phenotype
# 1267                 phenotype
#
# [1268 rows x 14 columns]

# %%
v2g_scored = pd.read_parquet("https://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/latest/v2g_scored/part-00000-f45b4766-6956-4139-be15-36bd714f7d47-c000.snappy.parquet")
print(v2g_scored.shape)
v2g_scored.head()
# Out:
# (1000000, 25)
#   chr_id  position ref_allele alt_allele          gene_id      feature  \
# 0      1     10291          C         CT  ENSG00000284733  unspecified
# 1      1     54380          T          C  ENSG00000186092  unspecified
# 2      1     55285          T          C  ENSG00000186092  unspecified
# 3      1     63325          T          C  ENSG00000284733  unspecified
# 4      1     72573          G          T  ENSG00000186092  unspecified
#
#     type_id      source_id fpred_labels fpred_scores fpred_max_label  \
# 0  distance  canonical_tss           []           []            None
# 1  distance  canonical_tss           []           []            None
# 2  distance  canonical_tss           []           []            None
# 3  distance  canonical_tss           []           []            None
# 4  distance  canonical_tss           []           []            None
#
#    fpred_max_score  qtl_beta  qtl_se  qtl_pval  qtl_score  interval_score  \
# 0              NaN       NaN     NaN       NaN        NaN             NaN
# 1              NaN       NaN     NaN       NaN        NaN             NaN
# 2              NaN       NaN     NaN       NaN        NaN             NaN
# 3              NaN       NaN     NaN       NaN        NaN             NaN
# 4              NaN       NaN     NaN       NaN        NaN             NaN
#
#    qtl_score_q  interval_score_q         d  distance_score  distance_score_q  \
# 0          NaN               NaN  441387.0        0.000002               0.1
# 1          NaN               NaN   11039.0        0.000091               1.0
# 2          NaN               NaN   10134.0        0.000099               1.0
# 3          NaN               NaN  388353.0        0.000003               0.2
# 4          NaN               NaN    7154.0        0.000140               1.0
#
#    overall_score      source_list source_score_list
# 0       0.006640  [canonical_tss]             [0.1]
# 1       0.066398  [canonical_tss]             [1.0]
# 2       0.066398  [canonical_tss]             [1.0]
# 3       0.013280  [canonical_tss]             [0.2]
# 4       0.066398  [canonical_tss]             [1.0]

# %%
d2v2g_scored = pd.read_parquet("https://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/latest/d2v2g_scored/part-00000-4496e3f4-9708-4c3a-a769-93d95c79b892-c000.snappy.parquet")
print(d2v2g_scored.shape)
d2v2g_scored.head()
# Out:
# (1000000, 64)
#   tag_chrom  tag_pos tag_ref tag_alt          gene_id      study_id source  \
# 0         1   901544       G       A  ENSG00000175756  GCST90025945   GCST
# 1         1   903007       T       C  ENSG00000078808  GCST90025945   GCST
# 2         1   911848       C       T  ENSG00000188290  GCST90025945   GCST
# 3         1   911848       C       T  ENSG00000188290  GCST90025945   GCST
# 4         1   911848       C       T  ENSG00000188290  GCST90025945   GCST
#
#             pmid    pub_date pub_journal  \
# 0  PMID:34226706  2021-07-05   Nat Genet
# 1  PMID:34226706  2021-07-05   Nat Genet
# 2  PMID:34226706  2021-07-05   Nat Genet
# 3  PMID:34226706  2021-07-05   Nat Genet
# 4  PMID:34226706  2021-07-05   Nat Genet
#
#                                            pub_title pub_author  has_sumstats  \
# 0  Whole-exome imputation within UK Biobank power...  Barton AR          True
# 1  Whole-exome imputation within UK Biobank power...  Barton AR          True
# 2  Whole-exome imputation within UK Biobank power...  Barton AR          True
# 3  Whole-exome imputation within UK Biobank power...  Barton AR          True
# 4  Whole-exome imputation within UK Biobank power...  Barton AR          True
#
#       trait_reported     trait_efos   ancestry_initial ancestry_replication  \
# 0  Cystatin C levels  [EFO_0004617]  [European=437846]                   []
# 1  Cystatin C levels  [EFO_0004617]  [European=437846]                   []
# 2  Cystatin C levels  [EFO_0004617]  [European=437846]                   []
# 3  Cystatin C levels  [EFO_0004617]  [European=437846]                   []
# 4  Cystatin C levels  [EFO_0004617]  [European=437846]                   []
#
#    n_initial  n_replication  n_cases trait_category  num_assoc_loci  \
# 0     437846            NaN      NaN    measurement             607
# 1     437846            NaN      NaN    measurement             607
# 2     437846            NaN      NaN    measurement             607
# 3     437846            NaN      NaN    measurement             607
# 4     437846            NaN      NaN    measurement             607
#
#   lead_chrom  lead_pos lead_ref lead_alt  overall_r2  AFR_1000G_prop  \
# 0          1    922671        C        T    0.517138             0.0
# 1          1    922671        C        T    0.517138             0.0
# 2          1    922671        C        T    0.726337             0.0
# 3          1    922671        C        T    0.726337             0.0
# 4          1    922671        C        T    0.726337             0.0
#
#    AMR_1000G_prop  EAS_1000G_prop  EUR_1000G_prop  SAS_1000G_prop  log10_ABF  \
# 0             0.0             0.0             1.0             0.0        NaN
# 1             0.0             0.0             1.0             0.0        NaN
# 2             0.0             0.0             1.0             0.0        NaN
# 3             0.0             0.0             1.0             0.0        NaN
# 4             0.0             0.0             1.0             0.0        NaN
#
#    posterior_prob  odds_ratio  oddsr_ci_lower  oddsr_ci_upper direction  \
# 0             NaN         NaN             NaN             NaN         -
# 1             NaN         NaN             NaN             NaN         -
# 2             NaN         NaN             NaN             NaN         -
# 3             NaN         NaN             NaN             NaN         -
# 4             NaN         NaN             NaN             NaN         -
#
#        beta  beta_ci_lower  beta_ci_upper  pval_mantissa  pval_exponent  \
# 0 -0.016747      -0.021301      -0.012194            7.0            -15
# 1 -0.016747      -0.021301      -0.012194            7.0            -15
# 2 -0.016747      -0.021301      -0.012194            7.0            -15
# 3 -0.016747      -0.021301      -0.012194            7.0            -15
# 4 -0.016747      -0.021301      -0.012194            7.0            -15
#
#            pval                 feature   type_id      source_id fpred_labels  \
# 0  7.000000e-15             unspecified  distance  canonical_tss           []
# 1  7.000000e-15             unspecified  distance  canonical_tss           []
# 2  7.000000e-15   CEDAR-NEUTROPHIL_CD15      eqtl           eqtl           []
# 3  7.000000e-15             unspecified  distance  canonical_tss           []
# 4  7.000000e-15  eQTLGen-UBERON_0000178      eqtl           eqtl           []
#
#   fpred_scores fpred_max_label  fpred_max_score  qtl_beta    qtl_se  \
# 0           []            None              NaN       NaN       NaN
# 1           []            None              NaN       NaN       NaN
# 2           []            None              NaN  0.324670  0.058582
# 3           []            None              NaN       NaN       NaN
# 4           []            None              NaN  0.172752  0.014979
#
#        qtl_pval  qtl_score  interval_score  qtl_score_q  interval_score_q  \
# 0           NaN        NaN             NaN          NaN               NaN
# 1           NaN        NaN             NaN          NaN               NaN
# 2  7.186620e-08   7.143475             NaN          0.4               NaN
# 3           NaN        NaN             NaN          NaN               NaN
# 4  8.974500e-31  30.046990             NaN          0.7               NaN
#
#           d  distance_score  distance_score_q  overall_score  \
# 0  473663.0        0.000002               0.1       0.006640
# 1  329024.0        0.000003               0.3       0.019920
# 2       NaN             NaN               NaN       0.146076
# 3   88324.0        0.000011               0.8       0.146076
# 4       NaN             NaN               NaN       0.146076
#
#              source_list source_score_list
# 0        [canonical_tss]             [0.1]
# 1        [canonical_tss]             [0.3]
# 2  [canonical_tss, eqtl]        [0.8, 0.7]
# 3  [canonical_tss, eqtl]        [0.8, 0.7]
# 4  [canonical_tss, eqtl]        [0.8, 0.7]

# %%
v2d = pd.read_parquet("https://ftp.ebi.ac.uk/pub/databases/opentargets/genetics/latest/v2d/part-00000-10068dba-939e-4873-be35-780fc4b12fcc-c000.snappy.parquet")
print(v2d.shape)
v2d.head()
# Out:
# (225545, 44)
#                   study_id lead_chrom  lead_pos lead_ref lead_alt direction  \
# 0           GCST006585_950          1   1008088        T        C         +
# 1  NEALE2_20003_1140867876          1   1010747       GT        G         -
# 2             GCST90087821          1   1009731        C        T         +
# 3             GCST90095130          1    994997        C        T         +
# 4             GCST90018954          1    993036        G        A         +
#
#        beta  beta_ci_lower  beta_ci_upper  odds_ratio  oddsr_ci_lower  \
# 0  0.735542       0.530600       0.940484         NaN             NaN
# 1       NaN            NaN            NaN    0.346424        0.237266
# 2  0.707278       0.556401       0.858155         NaN             NaN
# 3  5.840000       3.882404       7.797596         NaN             NaN
# 4  0.015400       0.010211       0.020589         NaN             NaN
#
#    oddsr_ci_upper  pval_mantissa  pval_exponent          pval  \
# 0             NaN        2.00000            -12  2.000000e-12
# 1        0.505801        4.02417             -8  4.024170e-08
# 2             NaN        4.00000            -20  4.000000e-20
# 3             NaN        5.00000             -9  5.000000e-09
# 4             NaN        6.00000             -9  6.000000e-09
#
#                        ancestry_initial ancestry_replication  n_cases  \
# 0                       [European=3200]                   []      NaN
# 1                     [European=361141]                   []    491.0
# 2                       [European=5366]                   []      NaN
# 3                      [European=33748]                   []      NaN
# 4  [European=344104, East Asian=133471]                   []      NaN
#
#    n_initial  n_replication           pmid      pub_author    pub_date  \
# 0       3200            NaN  PMID:30072576      Emilsson V  2018-08-02
# 1     361141            0.0           None    UKB Neale v2  2018-08-01
# 2       5366            NaN  PMID:35078996    Gudjonsson A  2022-01-25
# 3      33748            NaN  PMID:34910505  van der Meer D  2021-12-15
# 4     477575            NaN  PMID:34594039        Sakaue S  2021-09-30
#
#   pub_journal                                          pub_title  \
# 0     Science  Co-regulatory networks of human serum proteins...
# 1        None                                               None
# 2  Nat Commun  A genome-wide association study of serum prote...
# 3     Sci Adv  The genetic architecture of human cortical fol...
# 4   Nat Genet  A cross-population atlas of genetic associatio...
#
#    has_sumstats  num_assoc_loci source  \
# 0         False               1   GCST
# 1          True               6  NEALE
# 2         False               2   GCST
# 3         False             669   GCST
# 4         False             305   GCST
#
#                                     trait_reported     trait_efos  \
# 0          Blood protein levels [ISG15, 14151_4_3]  [EFO_0007937]
# 1  Prozac 20mg capsule | treatment/medication code  [EFO_0007010]
# 2                    Serum levels of protein ISG15  [EFO_0007937]
# 3                Vertex-wise cortical surface area  [EFO_0010736]
# 4                    Gamma glutamyl transpeptidase  [EFO_0004532]
#
#   trait_category tag_chrom  tag_pos tag_ref tag_alt  overall_r2  \
# 0    measurement         1   978812       G       C    0.595703
# 1    measurement         1   978812       G       C         NaN
# 2    measurement         1   978812       G       C    0.579132
# 3    measurement         1   986629       G       A    0.942542
# 4    measurement         1   986629       G       A    0.910355
#
#   pics_95perc_credset  AFR_1000G_prop  AMR_1000G_prop  EAS_1000G_prop  \
# 0               False             0.0             0.0        0.000000
# 1                None             NaN             NaN             NaN
# 2               False             0.0             0.0        0.000000
# 3                True             0.0             0.0        0.000000
# 4                True             0.0             0.0        0.279477
#
#    EUR_1000G_prop  SAS_1000G_prop  log10_ABF  posterior_prob
# 0        1.000000             0.0        NaN             NaN
# 1             NaN             NaN   4.345352         0.00226
# 2        1.000000             0.0        NaN             NaN
# 3        1.000000             0.0        NaN             NaN
# 4        0.720523             0.0        NaN             NaN
